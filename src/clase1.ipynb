# %%
# !pip install gzip
# Out:
# ERROR: Could not find a version that satisfies the requirement gzip (from versions: none)
# ERROR: No matching distribution found for gzip

# %%
import gzip
from google.colab import drive
import pandas as pandas
from statsmodels.tsa.arima.model import ARIMA

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe_history = pandas.read_csv("/content/drive/MyDrive/Austral - Laboratorio 3/tb_sellout_01.txt.gz", compression='gzip',
                                 header=0, sep=';', quotechar='"')
# Out:
# <ipython-input-6-de4795fc4fad>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe_history = pandas.read_csv("/content/drive/MyDrive/Austral - Laboratorio 3/tb_sellout_01.txt.gz", compression='gzip',

# %%
columns = []
data = {}
clean_data = []
with gzip.open("/content/drive/MyDrive/Austral - Laboratorio 3/tb_sellout_01.txt.gz", "rt") as f:
  for i, line in enumerate(f):
    clean_data.append(line)
    if i <= 4:
      columns.append(str(line))

  for index, column in enumerate(columns):
        data[column] = [line_clean.strip() for line_clean in clean_data[6 + index::6]]

# %%
dataframe = pandas.DataFrame(data)

# %%
dataframe
# Out:
#         periodo\n customer_id\n product_id\n cust_request_qty\n  \
# 0          201701         10234        20524                  2
# 1          201701         10032        20524                  1
# 2          201701         10217        20524                  1
# 3          201701         10125        20524                  1
# 4          201701         10012        20524                 11
# ...           ...           ...          ...                ...
# 2945813    201912         10105        20853                  1
# 2945814    201912         10092        20853                  1
# 2945815    201912         10006        20853                  7
# 2945816    201912         10018        20853                  4
# 2945817    201912         10020        20853                  2
#
#         cust_request_tn\n
# 0                   0.053
# 1                 0.13628
# 2                 0.03028
# 3                 0.02271
# 4                 1.54452
# ...                   ...
# ...

# %%
star_product_df = dataframe[dataframe["product_id\n"] == "20001"]

# %%
star_product_df
# Out:
#         periodo\n customer_id\n product_id\n cust_request_qty\n  \
# 44019      201701         10001        20001                 11
# 44020      201701         10063        20001                  1
# 44021      201701         10080        20001                  1
# 44022      201701         10094        20001                  1
# 44023      201701         10184        20001                  1
# ...           ...           ...          ...                ...
# 2909818    201912         10069        20001                  1
# 2909819    201912         10328        20001                  1
# 2909820    201912         10374        20001                  1
# 2909821    201912         10390        20001                  1
# 2909822    201912         10311        20001                  6
#
#         cust_request_tn\n
# 44019            99.43861
# 44020             0.12312
# 44021             0.24625
# 44022             1.23123
# 44023             0.06716
# ...                   ...
# ...

# %%
products = dataframe["product_id\n"].unique()
for index, product in enumerate(products):
  if index > 0:
    break
  product_df = dataframe[dataframe["product_id\n"] == product]
  print(product_df.dtypes)
  product_last_month_df = dataframe[product_df["periodo\n"] == "201902"]

  product_group = product_df.groupby("periodo\n").sum()
  print(product_group)
# Out:
# periodo\n             object
# customer_id\n         object
# product_id\n          object
# cust_request_qty\n    object
# cust_request_tn\n     object
# dtype: object
# <ipython-input-78-692b34fd2e01>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   product_last_month_df = dataframe[product_df["periodo\n"] == "201902"]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-78-692b34fd2e01> in <cell line: 2>()
#       5   product_df = dataframe[dataframe["product_id\n"] == product]
#       6   print(product_df.dtypes)
# ----> 7   product_last_month_df = dataframe[product_df["periodo\n"] == "201902"]
#       8
#       9   product_group = product_df.groupby("periodo\n").sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3796         # Do we have a (boolean) 1d indexer?
# ...
